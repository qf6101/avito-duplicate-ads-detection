# %%
# %%time 
from data.pair_feature import *
from data.original import item_pairs_train, item_pairs_test, item_info_train, item_info_test
from data.corpus_based import feature_nodes as corpus_based_feature_nodes
from data.dummy import dummy_features, categoryID_shuffle_features
from data.item import get_item, show_item_pair
import pandas as pd
import numpy as np
from xgboost.sklearn import XGBClassifier
from sklearn.cross_validation import train_test_split
n_train = 3344613
n_test = 1315205
import pickle
# Out:
# CPU times: user 3.9 s, sys: 3.22 s, total: 7.12 s
# Wall time: 20.4 s

# %%
def build_mxnet_header(model_names):
    header = ["line_num"]
    for name in model_names:
        header.extend('mxnet_{}_batch_{}_sim'.format(name, x) for x in  ['min', 'max', 'summean', 'mean'])
    return header

image_mxnet_features_train = pd.read_csv('data/data_files/image_mxnet_feature_train_bn.csv', names=build_mxnet_header(['bn']), index_col='line_num').sort_index()
image_mxnet_features_test = pd.read_csv('data/data_files/image_mxnet_feature_test_bn.csv', names=build_mxnet_header(['bn']), index_col='line_num').sort_index()

# %%
from feature.image_histogram_feature import header as image_histogram_feature_header
image_histogram_features_train = pd.read_csv('data/data_files/image_histogram_feature_train.csv', names = image_histogram_feature_header, index_col='index').sort_index()
image_histogram_features_test = pd.read_csv('data/data_files/image_histogram_feature_test.csv', names = image_histogram_feature_header, index_col='index').sort_index()

# %%
from feature.image_hash_feature import headers as image_hash_feature_headers

image_hash_features_train = pd.read_csv('data/data_files/image_hash_feature_train.csv',
                                       names=image_hash_feature_headers, index_col='index').sort_index()
image_hash_features_test = pd.read_csv('data/data_files/image_hash_feature_test.csv',
                                       names=image_hash_feature_headers, index_col='index').sort_index()

# %%
image_features_train = pd.concat((image_histogram_features_train, image_hash_features_train, image_mxnet_features_train), axis=1)
image_features_test = pd.concat((image_histogram_features_test, image_hash_features_test, image_mxnet_features_test), axis=1)

# %%
corpus_based_features = []
for node in corpus_based_feature_nodes:
    corpus_based_features.append(node.get_data())
corpus_based_features = pd.concat(corpus_based_features, axis=1)

# %%
corpus_based_features.shape
# Out:
# (4035592, 110)

# %%
def split_feats(feats):
    n_train = 2991396
    feats_train = feats[:n_train]
    feats_test = feats[n_train:]
    feats_test.index = simple_features_test.index.copy()
    return feats_train, feats_test

# %%
corpus_based_features_train, corpus_based_features_test = split_feats(corpus_based_features)
dummy_features_train, dummy_features_test = split_feats(dummy_features)
categoryID_shuffle_features_train, categoryID_shuffle_features_test = split_feats(categoryID_shuffle_features)

# %%
print(simple_features_train.shape[1])
print(aggregation_features_train.shape[1])
print(title_features_train.shape[1])
print(description_features_train.shape[1])
print(image_features_train.shape[1])
print(corpus_based_features_train.shape[1])
# print(categoryID_shuffle_features_train.shape[1])
# Out:
# 26
# 20
# 4
# 10
# 44
# 110

# %%
features_train = pd.concat((
        simple_features_train,
        aggregation_features_train,
        title_features_train, description_features_train,
        ncd_features_train,
        image_features_train,
        corpus_based_features_train,
        dummy_features_train,
        categoryID_shuffle_features_train,
    ), axis=1)
features_test = pd.concat((
        simple_features_test,
        aggregation_features_test,
        title_features_test, description_features_test,
        ncd_features_test,
        image_features_test, 
        corpus_based_features_test,
        dummy_features_test,
        categoryID_shuffle_features_test
    ), axis=1)

# %%
print(features_train.shape)
print(features_test.shape)
# Out:
# (2991396, 290)
# (1044196, 290)

# %%
weight_map = {
    1: 3,
    2: 1,
    3: 1
}

weight = np.empty(item_pairs_train.shape[0])
generationMethod = item_pairs_train.generationMethod.values
for i in [1,2,3]:
    weight[generationMethod==i] = weight_map[i]

# %%
# %%time
X_train, X_test, y_train, y_test, I_train, I_test =\
train_test_split(features_train.values, item_pairs_train.isDuplicate.values, np.arange(features_train.shape[0]),
                 test_size=0.2, random_state=42)
weight_train = weight[I_train]
# Out:
# CPU times: user 3min 27s, sys: 29.3 s, total: 3min 56s
# Wall time: 3min 57s

# %% [raw]
#     eta = 0.1
#     max_depth = 5
#     subsample = 0.8
#     colsample_bytree = 0.8
#     num_boost_round = 260
#     early_stopping_rounds = 20

# %%
model = XGBClassifier(learning_rate=0.05, max_depth=10, subsample=1, colsample_bytree=0.8, n_estimators=500,
                      min_child_weight = 1,
                      nthread=32)

# %%
model.fit(X_train, y_train, eval_metric='auc', eval_set=[(X_test, y_test)],  early_stopping_rounds=20)
# Out:
# [0]	validation_0-auc:0.932434
# Will train until validation_0-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.936084
# [2]	validation_0-auc:0.939251
# [3]	validation_0-auc:0.940383
# [4]	validation_0-auc:0.941008
# [5]	validation_0-auc:0.94168
# [6]	validation_0-auc:0.942284
# [7]	validation_0-auc:0.942762
# [8]	validation_0-auc:0.943242
# [9]	validation_0-auc:0.94366
# [10]	validation_0-auc:0.944016
# [11]	validation_0-auc:0.944275
# [12]	validation_0-auc:0.944648
# [13]	validation_0-auc:0.945084
# [14]	validation_0-auc:0.945342
# [15]	validation_0-auc:0.945872
# [16]	validation_0-auc:0.946113
# [17]	validation_0-auc:0.946409
# [18]	validation_0-auc:0.94667
# [19]	validation_0-auc:0.946953
# [20]	validation_0-auc:0.94726
# [21]	validation_0-auc:0.947525
# [22]	validation_0-auc:0.947729
# [23]	validation_0-auc:0.94798
# [24]	validation_0-auc:0.948206
# [25]	validation_0-auc:0.948424
# [26]	validation_0-auc:0.948613
# [27]	validation_0-auc:0.948881
# [28]	validation_0-auc:0.949085
# [29]	validation_0-auc:0.949308
# [30]	validation_0-auc:0.94944
# [31]	validation_0-auc:0.94965
# [32]	validation_0-auc:0.949884
# [33]	validation_0-auc:0.950039
# [34]	validation_0-auc:0.950246
# [35]	validation_0-auc:0.950426
# [36]	validation_0-auc:0.95061
# [37]	validation_0-auc:0.950795
# [38]	validation_0-auc:0.95097
# [39]	validation_0-auc:0.951113
# [40]	validation_0-auc:0.951269
# [41]	validation_0-auc:0.951403
# [42]	validation_0-auc:0.951543
# [43]	validation_0-auc:0.951714
# [44]	validation_0-auc:0.951881
# [45]	validation_0-auc:0.952019
# [46]	validation_0-auc:0.952175
# [47]	validation_0-auc:0.952302
# [48]	validation_0-auc:0.952433
# [49]	validation_0-auc:0.952565
# [50]	validation_0-auc:0.952695
# [51]	validation_0-auc:0.952856
# [52]	validation_0-auc:0.952986
# [53]	validation_0-auc:0.953127
# [54]	validation_0-auc:0.95327
# [55]	validation_0-auc:0.953439
# [56]	validation_0-auc:0.953581
# [57]	validation_0-auc:0.953732
# [58]	validation_0-auc:0.953885
# [59]	validation_0-auc:0.954012
# [60]	validation_0-auc:0.954144
# [61]	validation_0-auc:0.954263
# [62]	validation_0-auc:0.954378
# [63]	validation_0-auc:0.954489
# [64]	validation_0-auc:0.954615
# [65]	validation_0-auc:0.954765
# [66]	validation_0-auc:0.954868
# [67]	validation_0-auc:0.954952
# [68]	validation_0-auc:0.955069
# [69]	validation_0-auc:0.955181
# [70]	validation_0-auc:0.95529
# [71]	validation_0-auc:0.955403
# [72]	validation_0-auc:0.955508
# [73]	validation_0-auc:0.955624
# [74]	validation_0-auc:0.955727
# [75]	validation_0-auc:0.955843
# [76]	validation_0-auc:0.955954
# [77]	validation_0-auc:0.956048
# [78]	validation_0-auc:0.956151
# [79]	validation_0-auc:0.956276
# [80]	validation_0-auc:0.956379
# [81]	validation_0-auc:0.956489
# [82]	validation_0-auc:0.956604
# [83]	validation_0-auc:0.95672
# [84]	validation_0-auc:0.956837
# [85]	validation_0-auc:0.95691
# [86]	validation_0-auc:0.957018
# [87]	validation_0-auc:0.957104
# [88]	validation_0-auc:0.95722
# [89]	validation_0-auc:0.957291
# [90]	validation_0-auc:0.957377
# [91]	validation_0-auc:0.957482
# [92]	validation_0-auc:0.95755
# [93]	validation_0-auc:0.957688
# [94]	validation_0-auc:0.957774
# [95]	validation_0-auc:0.957864
# [96]	validation_0-auc:0.957938
# [97]	validation_0-auc:0.958059
# [98]	validation_0-auc:0.958155
# [99]	validation_0-auc:0.958235
# [100]	validation_0-auc:0.958307
# [101]	validation_0-auc:0.958402
# [102]	validation_0-auc:0.958483
# [103]	validation_0-auc:0.958561
# [104]	validation_0-auc:0.958636
# [105]	validation_0-auc:0.958724
# [106]	validation_0-auc:0.958796
# [107]	validation_0-auc:0.958869
# [108]	validation_0-auc:0.958946
# [109]	validation_0-auc:0.959015
# [110]	validation_0-auc:0.959084
# [111]	validation_0-auc:0.959154
# [112]	validation_0-auc:0.959222
# [113]	validation_0-auc:0.9593
# [114]	validation_0-auc:0.959374
# [115]	validation_0-auc:0.959447
# [116]	validation_0-auc:0.959511
# [117]	validation_0-auc:0.959579
# [118]	validation_0-auc:0.959675
# [119]	validation_0-auc:0.959724
# [120]	validation_0-auc:0.959777
# [121]	validation_0-auc:0.959829
# [122]	validation_0-auc:0.959901
# [123]	validation_0-auc:0.959948
# [124]	validation_0-auc:0.960007
# [125]	validation_0-auc:0.960067
# [126]	validation_0-auc:0.960109
# [127]	validation_0-auc:0.960175
# [128]	validation_0-auc:0.960235
# [129]	validation_0-auc:0.960294
# [130]	validation_0-auc:0.960342
# [131]	validation_0-auc:0.9604
# [132]	validation_0-auc:0.960444
# [133]	validation_0-auc:0.960496
# [134]	validation_0-auc:0.960539
# [135]	validation_0-auc:0.960599
# [136]	validation_0-auc:0.960646
# [137]	validation_0-auc:0.960711
# [138]	validation_0-auc:0.960755
# [139]	validation_0-auc:0.960795
# [140]	validation_0-auc:0.960849
# [141]	validation_0-auc:0.960907
# [142]	validation_0-auc:0.960936
# [143]	validation_0-auc:0.960981
# [144]	validation_0-auc:0.961035
# [145]	validation_0-auc:0.961079
# [146]	validation_0-auc:0.961122
# [147]	validation_0-auc:0.96115
# [148]	validation_0-auc:0.961195
# [149]	validation_0-auc:0.96123
# [150]	validation_0-auc:0.961276
# [151]	validation_0-auc:0.961321
# [152]	validation_0-auc:0.961364
# [153]	validation_0-auc:0.961406
# [154]	validation_0-auc:0.96146
# [155]	validation_0-auc:0.961495
# [156]	validation_0-auc:0.961544
# [157]	validation_0-auc:0.96158
# [158]	validation_0-auc:0.961623
# [159]	validation_0-auc:0.961655
# [160]	validation_0-auc:0.961701
# [161]	validation_0-auc:0.96174
# [162]	validation_0-auc:0.961781
# [163]	validation_0-auc:0.961818
# [164]	validation_0-auc:0.961853
# [165]	validation_0-auc:0.961882
# [166]	validation_0-auc:0.961933
# [167]	validation_0-auc:0.961973
# [168]	validation_0-auc:0.96201
# [169]	validation_0-auc:0.962048
# [170]	validation_0-auc:0.96209
# [171]	validation_0-auc:0.962123
# [172]	validation_0-auc:0.96217
# [173]	validation_0-auc:0.962191
# [174]	validation_0-auc:0.96222
# [175]	validation_0-auc:0.962238
# [176]	validation_0-auc:0.962278
# [177]	validation_0-auc:0.962318
# [178]	validation_0-auc:0.962366
# [179]	validation_0-auc:0.962395
# [180]	validation_0-auc:0.962421
# [181]	validation_0-auc:0.962449
# [182]	validation_0-auc:0.962484
# [183]	validation_0-auc:0.962512
# [184]	validation_0-auc:0.96254
# [185]	validation_0-auc:0.962586
# [186]	validation_0-auc:0.962613
# [187]	validation_0-auc:0.962629
# [188]	validation_0-auc:0.962673
# [189]	validation_0-auc:0.962701
# [190]	validation_0-auc:0.962728
# [191]	validation_0-auc:0.962745
# [192]	validation_0-auc:0.962763
# [193]	validation_0-auc:0.962787
# [194]	validation_0-auc:0.962807
# [195]	validation_0-auc:0.96283
# [196]	validation_0-auc:0.962855
# [197]	validation_0-auc:0.962882
# [198]	validation_0-auc:0.962905
# [199]	validation_0-auc:0.96293
# [200]	validation_0-auc:0.962951
# [201]	validation_0-auc:0.962972
# [202]	validation_0-auc:0.963012
# [203]	validation_0-auc:0.963037
# [204]	validation_0-auc:0.963057
# [205]	validation_0-auc:0.963077
# [206]	validation_0-auc:0.963091
# [207]	validation_0-auc:0.96311
# [208]	validation_0-auc:0.963135
# [209]	validation_0-auc:0.963157
# [210]	validation_0-auc:0.963178
# [211]	validation_0-auc:0.963203
# [212]	validation_0-auc:0.963226
# [213]	validation_0-auc:0.963243
# [214]	validation_0-auc:0.963257
# [215]	validation_0-auc:0.963281
# [216]	validation_0-auc:0.9633
# [217]	validation_0-auc:0.963324
# [218]	validation_0-auc:0.963352
# [219]	validation_0-auc:0.963374
# [220]	validation_0-auc:0.963398
# [221]	validation_0-auc:0.963416
# [222]	validation_0-auc:0.963439
# [223]	validation_0-auc:0.963473
# [224]	validation_0-auc:0.963485
# [225]	validation_0-auc:0.963506
# [226]	validation_0-auc:0.963524
# [227]	validation_0-auc:0.963547
# [228]	validation_0-auc:0.963564
# [229]	validation_0-auc:0.963593
# [230]	validation_0-auc:0.963607
# [231]	validation_0-auc:0.96362
# [232]	validation_0-auc:0.963641
# [233]	validation_0-auc:0.963654
# [234]	validation_0-auc:0.963675
# [235]	validation_0-auc:0.963693
# [236]	validation_0-auc:0.963717
# [237]	validation_0-auc:0.963737
# [238]	validation_0-auc:0.963767
# [239]	validation_0-auc:0.963792
# [240]	validation_0-auc:0.963817
# [241]	validation_0-auc:0.963823
# [242]	validation_0-auc:0.963848
# [243]	validation_0-auc:0.96387
# [244]	validation_0-auc:0.963897
# [245]	validation_0-auc:0.963917
# [246]	validation_0-auc:0.963931
# [247]	validation_0-auc:0.96394
# [248]	validation_0-auc:0.963956
# [249]	validation_0-auc:0.963973
# [250]	validation_0-auc:0.96399
# [251]	validation_0-auc:0.964004
# [252]	validation_0-auc:0.964031
# [253]	validation_0-auc:0.964042
# [254]	validation_0-auc:0.964064
# [255]	validation_0-auc:0.964076
# [256]	validation_0-auc:0.964086
# [257]	validation_0-auc:0.964105
# [258]	validation_0-auc:0.964115
# [259]	validation_0-auc:0.964124
# [260]	validation_0-auc:0.964138
# [261]	validation_0-auc:0.96415
# [262]	validation_0-auc:0.964163
# [263]	validation_0-auc:0.964173
# [264]	validation_0-auc:0.964178
# [265]	validation_0-auc:0.964186
# [266]	validation_0-auc:0.964211
# [267]	validation_0-auc:0.964224
# [268]	validation_0-auc:0.964238
# [269]	validation_0-auc:0.964262
# [270]	validation_0-auc:0.964274
# [271]	validation_0-auc:0.964291
# [272]	validation_0-auc:0.964309
# [273]	validation_0-auc:0.964326
# [274]	validation_0-auc:0.964341
# [275]	validation_0-auc:0.964354
# [276]	validation_0-auc:0.964373
# [277]	validation_0-auc:0.964386
# [278]	validation_0-auc:0.964405
# [279]	validation_0-auc:0.964415
# [280]	validation_0-auc:0.964428
# [281]	validation_0-auc:0.964437
# [282]	validation_0-auc:0.964449
# [283]	validation_0-auc:0.964468
# [284]	validation_0-auc:0.964486
# [285]	validation_0-auc:0.964494
# [286]	validation_0-auc:0.964511
# [287]	validation_0-auc:0.964525
# [288]	validation_0-auc:0.964533
# [289]	validation_0-auc:0.964552
# [290]	validation_0-auc:0.964569
# [291]	validation_0-auc:0.964581
# [292]	validation_0-auc:0.964598
# [293]	validation_0-auc:0.964608
# [294]	validation_0-auc:0.964626
# [295]	validation_0-auc:0.964642
# [296]	validation_0-auc:0.964656
# [297]	validation_0-auc:0.964667
# [298]	validation_0-auc:0.964681
# [299]	validation_0-auc:0.964689
# [300]	validation_0-auc:0.964702
# [301]	validation_0-auc:0.964722
# [302]	validation_0-auc:0.964726
# [303]	validation_0-auc:0.964738
# [304]	validation_0-auc:0.96475
# [305]	validation_0-auc:0.964769
# [306]	validation_0-auc:0.964783
# [307]	validation_0-auc:0.964796
# [308]	validation_0-auc:0.964802
# [309]	validation_0-auc:0.964816
# [310]	validation_0-auc:0.964824
# [311]	validation_0-auc:0.964832
# [312]	validation_0-auc:0.964839
# [313]	validation_0-auc:0.964842
# [314]	validation_0-auc:0.964864
# [315]	validation_0-auc:0.964877
# [316]	validation_0-auc:0.964883
# [317]	validation_0-auc:0.964893
# [318]	validation_0-auc:0.964902
# [319]	validation_0-auc:0.964911
# [320]	validation_0-auc:0.964921
# [321]	validation_0-auc:0.964941
# [322]	validation_0-auc:0.96496
# [323]	validation_0-auc:0.964979
# [324]	validation_0-auc:0.964991
# [325]	validation_0-auc:0.965008
# [326]	validation_0-auc:0.965017
# [327]	validation_0-auc:0.965024
# [328]	validation_0-auc:0.965027
# [329]	validation_0-auc:0.965047
# [330]	validation_0-auc:0.965059
# [331]	validation_0-auc:0.965069
# [332]	validation_0-auc:0.965078
# [333]	validation_0-auc:0.965096
# [334]	validation_0-auc:0.965102
# [335]	validation_0-auc:0.965106
# [336]	validation_0-auc:0.965119
# [337]	validation_0-auc:0.965132
# [338]	validation_0-auc:0.965142
# [339]	validation_0-auc:0.96515
# [340]	validation_0-auc:0.965159
# [341]	validation_0-auc:0.965165
# [342]	validation_0-auc:0.965177
# [343]	validation_0-auc:0.965193
# [344]	validation_0-auc:0.965199
# [345]	validation_0-auc:0.965206
# [346]	validation_0-auc:0.965221
# [347]	validation_0-auc:0.965233
# [348]	validation_0-auc:0.965239
# [349]	validation_0-auc:0.965254
# [350]	validation_0-auc:0.965259
# [351]	validation_0-auc:0.965271
# [352]	validation_0-auc:0.965274
# [353]	validation_0-auc:0.965276
# [354]	validation_0-auc:0.965287
# [355]	validation_0-auc:0.965302
# [356]	validation_0-auc:0.96531
# [357]	validation_0-auc:0.965326
# [358]	validation_0-auc:0.965328
# [359]	validation_0-auc:0.965338
# [360]	validation_0-auc:0.965343
# [361]	validation_0-auc:0.965353
# [362]	validation_0-auc:0.965369
# [363]	validation_0-auc:0.965381
# [364]	validation_0-auc:0.965387
# [365]	validation_0-auc:0.965389
# [366]	validation_0-auc:0.965392
# [367]	validation_0-auc:0.965393
# [368]	validation_0-auc:0.9654
# [369]	validation_0-auc:0.965418
# [370]	validation_0-auc:0.965428
# [371]	validation_0-auc:0.965437
# [372]	validation_0-auc:0.965448
# [373]	validation_0-auc:0.965456
# [374]	validation_0-auc:0.965459
# [375]	validation_0-auc:0.965464
# [376]	validation_0-auc:0.965475
# [377]	validation_0-auc:0.965492
# [378]	validation_0-auc:0.965501
# [379]	validation_0-auc:0.96551
# [380]	validation_0-auc:0.965517
# [381]	validation_0-auc:0.96552
# [382]	validation_0-auc:0.965527
# [383]	validation_0-auc:0.965531
# [384]	validation_0-auc:0.965539
# [385]	validation_0-auc:0.96555
# [386]	validation_0-auc:0.965553
# [387]	validation_0-auc:0.965566
# [388]	validation_0-auc:0.965573
# [389]	validation_0-auc:0.965576
# [390]	validation_0-auc:0.965579
# [391]	validation_0-auc:0.965583
# [392]	validation_0-auc:0.965598
# [393]	validation_0-auc:0.965606
# [394]	validation_0-auc:0.965616
# [395]	validation_0-auc:0.965624
# [396]	validation_0-auc:0.965634
# [397]	validation_0-auc:0.965644
# [398]	validation_0-auc:0.965645
# [399]	validation_0-auc:0.965649
# [400]	validation_0-auc:0.96566
# [401]	validation_0-auc:0.965666
# [402]	validation_0-auc:0.965679
# [403]	validation_0-auc:0.965697
# [404]	validation_0-auc:0.965705
# [405]	validation_0-auc:0.965715
# [406]	validation_0-auc:0.965721
# [407]	validation_0-auc:0.965722
# [408]	validation_0-auc:0.965728
# [409]	validation_0-auc:0.965738
# [410]	validation_0-auc:0.96574
# [411]	validation_0-auc:0.965749
# [412]	validation_0-auc:0.965753
# [413]	validation_0-auc:0.965761
# [414]	validation_0-auc:0.965772
# [415]	validation_0-auc:0.965785
# [416]	validation_0-auc:0.965794
# [417]	validation_0-auc:0.965796
# [418]	validation_0-auc:0.9658
# [419]	validation_0-auc:0.965804
# [420]	validation_0-auc:0.965817
# [421]	validation_0-auc:0.965822
# [422]	validation_0-auc:0.96583
# [423]	validation_0-auc:0.965844
# [424]	validation_0-auc:0.965852
# [425]	validation_0-auc:0.965856
# [426]	validation_0-auc:0.96587
# [427]	validation_0-auc:0.965872
# [428]	validation_0-auc:0.965884
# [429]	validation_0-auc:0.965894
# [430]	validation_0-auc:0.965901
# [431]	validation_0-auc:0.965911
# [432]	validation_0-auc:0.965929
# [433]	validation_0-auc:0.965945
# [434]	validation_0-auc:0.965946
# [435]	validation_0-auc:0.965949
# [436]	validation_0-auc:0.965966
# [437]	validation_0-auc:0.965973
# [438]	validation_0-auc:0.965982
# [439]	validation_0-auc:0.965988
# [440]	validation_0-auc:0.96599
# [441]	validation_0-auc:0.965997
# [442]	validation_0-auc:0.965998
# [443]	validation_0-auc:0.966005
# [444]	validation_0-auc:0.96601
# [445]	validation_0-auc:0.966016
# [446]	validation_0-auc:0.966017
# [447]	validation_0-auc:0.966034
# [448]	validation_0-auc:0.966035
# [449]	validation_0-auc:0.966038
# [450]	validation_0-auc:0.966044
# [451]	validation_0-auc:0.966045
# [452]	validation_0-auc:0.966057
# [453]	validation_0-auc:0.966068
# [454]	validation_0-auc:0.966075
# [455]	validation_0-auc:0.966077
# [456]	validation_0-auc:0.966079
# [457]	validation_0-auc:0.966083
# [458]	validation_0-auc:0.966086
# [459]	validation_0-auc:0.966095
# [460]	validation_0-auc:0.966108
# [461]	validation_0-auc:0.966119
# [462]	validation_0-auc:0.966128
# [463]	validation_0-auc:0.966134
# [464]	validation_0-auc:0.966141
# [465]	validation_0-auc:0.966147
# [466]	validation_0-auc:0.966151
# [467]	validation_0-auc:0.966152
# [468]	validation_0-auc:0.966157
# [469]	validation_0-auc:0.966161
# [470]	validation_0-auc:0.966169
# [471]	validation_0-auc:0.966177
# [472]	validation_0-auc:0.96618
# [473]	validation_0-auc:0.966189
# [474]	validation_0-auc:0.966195
# [475]	validation_0-auc:0.966203
# [476]	validation_0-auc:0.96621
# [477]	validation_0-auc:0.966213
# [478]	validation_0-auc:0.966225
# [479]	validation_0-auc:0.966228
# [480]	validation_0-auc:0.966232
# [481]	validation_0-auc:0.966237
# [482]	validation_0-auc:0.966239
# [483]	validation_0-auc:0.966241
# [484]	validation_0-auc:0.966243
# [485]	validation_0-auc:0.966251
# [486]	validation_0-auc:0.966253
# [487]	validation_0-auc:0.966259
# [488]	validation_0-auc:0.96627
# [489]	validation_0-auc:0.966275
# [490]	validation_0-auc:0.966285
# [491]	validation_0-auc:0.966286
# [492]	validation_0-auc:0.966288
# [493]	validation_0-auc:0.966296
# [494]	validation_0-auc:0.966303
# [495]	validation_0-auc:0.966309
# [496]	validation_0-auc:0.966313
# [497]	validation_0-auc:0.966321
# [498]	validation_0-auc:0.966327
# [499]	validation_0-auc:0.966332
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=10,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=32,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
# %time pred_test = model.predict_proba(X_test)[:,1]
# Out:
# CPU times: user 1min 43s, sys: 2.16 s, total: 1min 46s
# Wall time: 39.6 s

# %%
eval_set = item_pairs_train.iloc[I_test]
eval_set['prob_predicted'] = pred_test
# Out:
# /home/idm/.local/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
from bokeh.io import output_notebook, show
from bokeh.charts import Histogram
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f6efcc70-ae07-48e1-babf-3459406daf5c">Loading BokehJS ...</span>
#     </div>

# %%
from ml_metrics import auc

# %%
eval_set.groupby('isDuplicate')['prob_predicted'].mean()
# Out:
# isDuplicate
# 0    0.124484
# 1    0.827428
# Name: prob_predicted, dtype: float32

# %%
eval_set.groupby('isDuplicate')['prob_predicted'].std()
# Out:
# isDuplicate
# 0    0.196732
# 1    0.246477
# Name: prob_predicted, dtype: float32

# %%
from data.dummy import mergeLeftInOrder2

# %%
eval_set = mergeLeftInOrder2(eval_set, item_info_train[['categoryID']], left_on='itemID_1', right_index=True)

# %%
auc_by_category = eval_set.groupby('categoryID')[['isDuplicate', 'prob_predicted']].apply(lambda x: auc(x['isDuplicate'].values, x['prob_predicted'].values))

# %%
auc_by_category.order()
# Out:
# /home/idm/.local/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: order is deprecated, use sort_values(...)
#   if __name__ == '__main__':
# categoryID
# 112    0.861898
# 85     0.902402
# 33     0.914760
# 111    0.920949
# 105    0.926524
# 101    0.929792
# 31     0.935724
# 99     0.935863
# 10     0.941604
# 23     0.946223
# 97     0.949035
# 98     0.950030
# 19     0.950759
# 26     0.951343
# 25     0.952084
# 32     0.952663
# 86     0.952899
# 115    0.955378
# 34     0.956140
# 42     0.956171
# 24     0.958461
# 21     0.958798
# 40     0.960437
# 87     0.960494
# 39     0.961754
# 84     0.961862
# 96     0.964935
# 29     0.967048
# 83     0.967535
# 36     0.968038
# 102    0.968630
# 38     0.968755
# 90     0.969396
# 27     0.969502
# 28     0.973903
# 94     0.975563
# 20     0.975588
# 114    0.976178
# 89     0.978343
# 9      0.978396
# 106    0.979690
# 88     0.982304
# 93     0.983249
# 30     0.984044
# 81     0.984905
# 82     0.985275
# 14     0.986669
# 92     0.987034
# 91     0.990017
# 11     0.990300
# 116    0.993248
# dtype: float64

# %%
from bokeh.charts import Bar

# %%
show(Bar(auc_by_category.order()))
# Out:
# /home/idm/.local/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: order is deprecated, use sort_values(...)
#   if __name__ == '__main__':
#     <div class="plotdiv" id="b17602e5-b738-4a6d-b0c1-7f8d03feb794"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b17602e5-b738-4a6d-b0c1-7f8d03feb794");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b17602e5-b738-4a6d-b0c1-7f8d03feb794' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8a3101a8-1546-4928-a3d5-fc8663f2e8d9":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"index":26}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.9513431016002241],"index":[26],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["26"],"y":[0.47567155080011203]}},"id":"fa0a6102-8c2a-49ff-a496-24eef0ebf084","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"index":39}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.9617537725996418],"index":[39],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["39"],"y":[0.4808768862998209]}},"id":"04173b4b-15c0-44a4-a419-f115528bcca6","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3094a9e6-173a-4010-a16e-ce6d6f34bc0d","type":"ColumnDataSource"},"glyph":{"id":"c0a37973-76b3-40fd-bd13-1acc06a54d5a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5feb7c3f-68a6-46e3-8800-c6ec43ba72f2","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"61ffbf00-2dd7-468f-9f7f-1208d716f03b","type":"ColumnDataSource"},"glyph":{"id":"c7736182-f43e-4815-91fd-afb44547aa29","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a1122d7f-d279-41e9-87bb-5c7ae4e25356","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ba33b328-d536-40ca-bf13-41f1d54b3806","type":"Rect"},{"attributes":{"axis_label":"Sum( A )","formatter":{"id":"8d1677e0-aa17-45a2-b7b4-22487acbabc3","type":"BasicTickFormatter"},"plot":{"id":"a18d6d63-c2a0-4e73-b556-70062ace0fc6","subtype":"Chart","type":"Plot"},"ticker":{"id":"969273e8-53f0-41ce-9e40-18fec421a60d","type":"BasicTicker"}},"id":"858f326e-8280-452b-817f-277fb407dcf5","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"index":30}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.9840437706573746],"index":[30],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["30"],"y":[0.4920218853286873]}},"id":"be43ea4e-3b81-483e-875e-91d9e3c453b9","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cc7ef828-5654-4dfc-8c90-b487c0a571cc","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"index":42}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.956171477302343],"index":[42],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["42"],"y":[0.4780857386511715]}},"id":"d574aef5-fa15-4fa3-941c-09afeab84bb1","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"76e3aa3b-dbee-4a05-8b8e-ac40804aa818","type":"ColumnDataSource"},"glyph":{"id":"a02f63fa-f63a-466a-95e4-e44ab13fef3f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"bd107ca4-e4c2-4aec-8b23-d825244a063c","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"bd31cd97-2f63-406c-94bf-32680405919d","type":"ColumnDataSource"},"glyph":{"id":"63d46eb3-5f0a-4f47-838c-f19b8f4b4304","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5cfd7e3f-7616-41fd-9403-7fc81e0fa8d7","type":"GlyphRenderer"},{"attributes":{"data_source":{" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[51]</strong>&gt;</code></p>

# %%
eval_set.shape[0]
# Out:
# 598280

# %%
p = Histogram(eval_set.head(5000), values='prob_predicted', color='isDuplicate', bins=30, legend=True, plot_width=1000)
show(p)
# Out:
#     <div class="plotdiv" id="a456f86d-8f1c-4161-b07a-0e536412554f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a456f86d-8f1c-4161-b07a-0e536412554f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a456f86d-8f1c-4161-b07a-0e536412554f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cdb396b8-a2c6-454b-b2c7-6d2bb60494c3":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"index":26}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.9513431016002241],"index":[26],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["26"],"y":[0.47567155080011203]}},"id":"fa0a6102-8c2a-49ff-a496-24eef0ebf084","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"5df50b7e-c7ed-42d6-bfb3-be5c379b7d04","type":"ColumnDataSource"},"glyph":{"id":"64ac9f37-b64a-4a9b-b737-dada7ec39593","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"88f90556-907a-4399-8a9d-2c6f01fa5914","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"index":39}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.9617537725996418],"index":[39],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["39"],"y":[0.4808768862998209]}},"id":"04173b4b-15c0-44a4-a419-f115528bcca6","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"isDuplicate":1}],"color":["#5ab738"],"fill_alpha":[0.6],"height":[126.0],"isDuplicate":[1],"line_alpha":[1.0],"line_color":["black"],"width":[0.03395000000000001],"x":["0.915"],"y":[63.0]}},"id":"789cb0d8-eae2-4e66-82b4-89cfb1e7c19f","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"f797c55a-ec3a-44b8-934d-bdc64989fb2c","subtype":"Chart","type":"Plot"}},"id":"80c06002-0881-4621-a451-0e5ab5a73646","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"index":40}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.9604367713742212],"index":[40],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["40"],"y":[0.4802183856871106]}},"id":"6978881b-3f2a-4df2-8a7d-f7a3e35725fe","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e3eccef5-7326-40c5-89f4-d8128e16746b","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"451757ac-0e82-4272-b76c-69c3248cf6da","type":"Rect"},{"attributes":{},"id":"42684e08-607f-4440-a71a-edb0ab774c3a","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bd52a380-da5d-419d-a340-4ad986838f27","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"55d1e41d-593c-4be0-8b56-d62b223caa32","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e1933f34-3f5b-48d9-95a1-9c7d391e3820","type":"Rect"},{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"isDuplicate":1}],"color":["#5ab738"],"fill_alpha":[0.6],"height":[15.0],"isDuplicate":[1] ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[53]</strong>&gt;</code></p>

# %% [raw]
# eval_set[(eval_set.prob_predicted>=0.8) & (eval_set.prob_predicted <=1.0)].sort(['isDuplicate', 'prob_predicted']).head()

# %% [raw]
# eval_set[(eval_set.prob_predicted<=0.2)].sort(['isDuplicate', 'prob_predicted'], ascending=False).head()

# %%
feature_importance = pd.DataFrame({'feature': features_train.columns,
              'importance': model.feature_importances_}).sort('importance', ascending=False)
# Out:
# /home/idm/.local/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %%
from bokeh.charts import Bar
from bokeh.charts.attributes import CatAttr

# %%
feature_importance.head(50)
# Out:
#                                            feature  importance
# 180  title_word_1_2gram_dtm_0_predict_log_price__1    0.015352
# 181  title_word_1_2gram_dtm_0_predict_log_price__2    0.015343
# 107                        mxnet_bn_batch_mean_sim    0.014696
# 4                           description_length_max    0.014154
# 5                           description_length_min    0.013829
# 11                                      price_diff    0.013002
# 184   title_description_dtm_0_predict_log_price__1    0.012954
# 185   title_description_dtm_0_predict_log_price__2    0.012500
# 105                         mxnet_bn_batch_max_sim    0.011103
# 14                                       price_min    0.010932
# 30                               locationID_1_freq    0.010878
# 13                                       price_max    0.010721
# 43                              title_2_price_mean    0.010459
# 12                                price_diff_ratio    0.010404
# 63                                title_snappy_ncd    0.010339
# 0                           attrsJSON_item_jaccard    0.010256
# 39                              title_1_price_mean    0.010182
# 106                     mxnet_bn_batch_summean_sim    0.010048
# 104                         mxnet_bn_batch_min_sim    0.010017
# 62                                   title_bz2_ncd    0.009241
# 34                               locationID_2_freq    0.009110
# 168   description_word_dtm_0__max_disjoint_idf_min    0.008754
# 45                               title_2_price_std    0.008611
# 41                               title_1_price_std    0.008545
# 44                            title_2_price_median    0.008486
# 25                                title_length_min    0.008297
# 31                         locationID_1_price_mean    0.008232
# 32                       locationID_1_price_median    0.008106
# 60                             description_bz2_ncd    0.007784
# 40                            title_1_price_median    0.007573
# 10                               location_distance    0.007530
# 46                       title_edit_distance_ratio    0.007402
# 47                                        title_jw    0.007385
# 35                         locationID_2_price_mean    0.007356
# 36                       locationID_2_price_median    0.007254
# 50                 description_edit_distance_ratio    0.006840
# 24                                title_length_max    0.006780
# 33                          locationID_1_price_std    0.006752
# 37                          locationID_2_price_std    0.006695
# 51                                  description_jw    0.006669
# 176   title_word_2gram_dtm_0__max_disjoint_idf_min    0.006669
# 170   description_word_dtm_1__max_disjoint_idf_min    0.006635
# 61                          description_snappy_ncd    0.006415
# 159                     description_word_nmf_0_1_1    0.006330
# 155                     description_word_lsa_0_1_1    0.006239
# 38                                    title_1_freq    0.006068
# 152                             title_word_lsa_0_1    0.006059
# 3                    description_length_diff_ratio    0.006028
# 160         title_word_dtm_0__max_disjoint_idf_min    0.005988
# 27                           categoryID_price_mean    0.005922

# %%
feature_importance.tail(50)
# Out:
#               feature  importance
# 230     categoryID_28    0.000242
# 235     categoryID_33    0.000240
# 251     categoryID_90    0.000208
# 222     categoryID_19    0.000202
# 257     categoryID_97    0.000202
# 267    categoryID_115    0.000171
# 236     categoryID_34    0.000160
# 224     categoryID_21    0.000154
# 218      categoryID_9    0.000123
# 244     categoryID_83    0.000120
# 231     categoryID_29    0.000120
# 264    categoryID_111    0.000120
# 219     categoryID_10    0.000117
# 249     categoryID_88    0.000111
# 245     categoryID_84    0.000111
# 266    categoryID_114    0.000111
# 260    categoryID_101    0.000108
# 223     categoryID_20    0.000083
# 239     categoryID_39    0.000083
# 243     categoryID_82    0.000074
# 255     categoryID_94    0.000071
# 234     categoryID_32    0.000066
# 265    categoryID_112    0.000063
# 256     categoryID_96    0.000063
# 238     categoryID_38    0.000054
# 233     categoryID_31    0.000054
# 254     categoryID_93    0.000051
# 16   same_description    0.000048
# 229     categoryID_27    0.000048
# 226     categoryID_24    0.000046
# 258     categoryID_98    0.000043
# 246     categoryID_85    0.000040
# 21         same_title    0.000037
# 241     categoryID_42    0.000031
# 262    categoryID_105    0.000031
# 259     categoryID_99    0.000031
# 227     categoryID_25    0.000026
# 252     categoryID_91    0.000026
# 261    categoryID_102    0.000023
# 248     categoryID_87    0.000020
# 228     categoryID_26    0.000020
# 242     categoryID_81    0.000020
# 225     categoryID_23    0.000020
# 220     categoryID_11    0.000020
# 268    categoryID_116    0.000017
# 221     categoryID_14    0.000014
# 263    categoryID_106    0.000014
# 247     categoryID_86    0.000000
# 15    same_categoryID    0.000000
# 253     categoryID_92    0.000000

# %%
corpus_based_features.columns
# Out:
# Index(['title_word_dtm_0__tf__cosine', 'title_word_dtm_0__binary_tf__cosine',
#        'title_word_dtm_0__tfidf__cosine',
#        'title_word_dtm_0__binary_tfidf__cosine',
#        'title_word_dtm_1__tf__cosine', 'title_word_dtm_1__binary_tf__cosine',
#        'title_word_dtm_1__tfidf__cosine',
#        'title_word_dtm_1__binary_tfidf__cosine',
#        'title_word_dtm_0_1__tf__cosine',
#        'title_word_dtm_0_1__binary_tf__cosine',
#        ...
#        'description_sentence_word_dtm_1__binary_tf__cosine_similarity__0_mean',
#        'description_sentence_word_dtm_1__binary_tf__cosine_similarity__1_min',
#        'description_sentence_word_dtm_1__binary_tf__cosine_similarity__1_max',
#        'description_sentence_word_dtm_1__binary_tf__cosine_similarity__1_mean',
#        'description_sentence_word_dtm_1_1__binary_tf__cosine_similarity__0_min',
#        'description_sentence_word_dtm_1_1__binary_tf__cosine_similarity__0_max',
#        'description_sentence_word_dtm_1_1__binary_tf__cosine_similarity__0_mean',
#        'description_sentence_word_dtm_1_1__binary_tf__cosine_similarity__1_min',
#        'description_sentence_word_dtm_1_1__binary_tf__cosine_similarity__1_max',
#        'description_sentence_word_dtm_1_1__binary_tf__cosine_similarity__1_mean'],
#       dtype='object', length=110)

# %%
item_info_train.shape[0] + item_info_test.shape[0]
# Out:
# 4659818

# %%
bst = model.booster()
bst.feature_names = features_train.columns.tolist()
print(pd.Series(bst.get_score(importance_type='gain')).sort_values(ascending=False).head(50))
print(pd.Series(bst.get_score(importance_type='cover')).sort_values(ascending=False).head(50))
# Out:
# image_phash_hamming_0_min                         2875.218537
# mxnet_bn_batch_max_sim                            1869.406305
# categoryID_112                                    1714.816033
# title_word_dtm_0_1__binary_tfidf__cosine          1053.358729
# image_dhash_hamming_0_min                          811.860253
# title_word_dtm_0_1__tfidf__cosine                  359.690265
# categoryID_9                                       311.754781
# categoryID_33                                      275.383379
# categoryID_111                                     254.657611
# price_diff_ratio                                   254.372805
# image_phash_hamming_0_mean                         250.078365
# categoryID_84                                      239.853817
# title_word_dtm_0_1__max_disjoint_idf_min           190.558471
# image_phash_jaccard                                184.227701
# categoryID_price_std                               183.384268
# categoryID_36                                      179.627319
# categoryID_101                                     178.676984
# same_price                                         172.998019
# categoryID_price_mean                              147.126062
# mxnet_bn_batch_summean_sim                         146.117476
# images_count_diff_ratio                            139.633963
# image_dhash_jaccard                                139.585524
# attrsJSON_item_jaccard                             128.500604
# title_word_2gram_dtm_0__max_disjoint_idf_min       114.661979
# image_ahash_jaccard                                105.281465
# categoryID_shuffle_10                              100.363472
# categoryID_price_median                            100.032720
# categoryID_shuffle_16                               92.187017
# categoryID_20                                       92.024340
# categoryID                                          88.503398
# same_locationID                                     88.169460
# description_word_dtm_0_1__binary_tfidf__cosine      85.120200
# categoryID_shuffle_12                               83.067224
# image_whash_jaccard                                 82.735152
# description_word_dtm_0_1__max_disjoint_idf_min      82.663964
# categoryID_40                                       80.765651
# categoryID_shuffle_15                               79.166284
# categoryID_83                                       76.138663
# categoryID_82                                       72.655967
# categoryID_shuffle_4                                69.327084
# price_diff                                          66.364507
# categoryID_116                                      66.106183
# categoryID_shuffle_7                                65.346842
# categoryID_shuffle_1                                61.032946
# categoryID_freq                                     59.040583
# categoryID_shuffle_13                               57.076474
# description_length_max                              55.283713
# images_count_min                                    53.967068
# description_word_dtm_0__binary_tfidf__cosine        53.705316
# categoryID_34                                       53.583245
# dtype: float64
# categoryID_11                                     94097.487143
# categoryID_14                                     65621.801040
# categoryID_112                                    39569.350750
# categoryID_34                                     36538.002599
# categoryID_83                                     33156.553365
# categoryID_87                                     29007.213580
# categoryID_111                                    28333.982857
# categoryID_91                                     22480.767111
# categoryID_9                                      21282.936442
# title_word_dtm_0_1__binary_tfidf__cosine          20622.542875
# categoryID_33                                     18674.035131
# categoryID_36                                     18603.428805
# categoryID_38                                     17355.578911
# images_count_min                                  13555.312504
# categoryID_21                                     13290.697811
# categoryID_40                                     13227.519838
# title_word_dtm_0_1__max_disjoint_idf_min          12019.860534
# categoryID_96                                     11661.258891
# categoryID_20                                     11314.366703
# price_diff_ratio                                  11175.384583
# categoryID_94                                     11074.540558
# categoryID_24                                     10230.284087
# title_word_2gram_dtm_0_1__binary_tf__cosine       10136.521574
# categoryID_93                                     10042.791222
# categoryID_90                                      9571.997397
# categoryID_97                                      8850.514863
# categoryID_23                                      8754.335329
# mxnet_bn_batch_max_sim                             8628.630991
# title_word_dtm_0_1__tfidf__cosine                  7881.507654
# description_word_dtm_0_1__binary_tfidf__cosine     7840.640592
# title_word_2gram_dtm_0__binary_tfidf__cosine       7825.684451
# image_phash_hamming_0_min                          7766.519815
# attrsJSON_key_jaccard                              7553.013575
# attrsJSON_item_jaccard                             7551.238316
# categoryID_115                                     7270.501213
# same_price                                         7218.852000
# categoryID_89                                      7198.836921
# categoryID_price_std                               7041.965145
# categoryID_30                                      6774.017494
# description_word_dtm_0_1__max_disjoint_idf_min     6740.830205
# categoryID_114                                     6652.509969
# categoryID_88                                      6391.193679
# categoryID_82                                      6387.897423
# title_word1_jaccard                                6345.745992
# title_word0_jaccard                                6089.236130
# title_word_dtm_1__tf__cosine                       6073.351096
# categoryID_116                                     5985.073500
# price_diff                                         5984.911608
# categoryID_28                                      5861.155807
# description_word1_jaccard                          5839.987065
# dtype: float64

# %%
feature_importance.set_index('feature').loc[corpus_based_features.columns].sort('importance', ascending=False)
# Out:
# /home/idm/.local/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                                     importance
# title_word_1_2gram_dtm_0_predict_log_price__1         0.015352
# title_word_1_2gram_dtm_0_predict_log_price__2         0.015343
# title_description_dtm_0_predict_log_price__1          0.012954
# title_description_dtm_0_predict_log_price__2          0.012500
# description_word_dtm_0__max_disjoint_idf_min          0.008754
# title_word_2gram_dtm_0__max_disjoint_idf_min          0.006669
# description_word_dtm_1__max_disjoint_idf_min          0.006635
# description_word_nmf_0_1_1                            0.006330
# description_word_lsa_0_1_1                            0.006239
# title_word_lsa_0_1                                    0.006059
# title_word_dtm_0__max_disjoint_idf_min                0.005988
# title_word_nmf_0_1                                    0.005706
# description_word_dtm_1__max_disjoint_idf_max          0.005688
# description_word_dtm_0__max_disjoint_idf_max          0.005668
# title_word_lsa_0_1_1                                  0.005472
# title_word_dtm_0__max_disjoint_idf_max                0.005466
# description_word_lsa_0_1                              0.005446
# title_word_nmf_0_1_1                                  0.005323
# log_price__2                                          0.005246
# title_word_dtm_1__max_disjoint_idf_max                0.004904
# description_word_nmf_0_1                              0.004745
# title_word_2gram_dtm_0_1__max_disjoint_idf_min        0.004611
# description_word2vec_news                             0.004491
# title_word2vec_web                                    0.004477
# description_word2vec_web                              0.004448
# title_word2vec_ruwikiruscorpora                       0.004437
# title_word2vec_news                                   0.004428
# title_word_dtm_1__max_disjoint_idf_min                0.004397
# description_word_dtm_0_1__binary_tfidf__cosine        0.004254
# description_word2vec_ruscorpora                       0.004243
# ...                                                        ...
# title_word_dtm_1__tfidf__cosine                       0.001451
# title_word_dtm_0__binary_tfidf__cosine                0.001451
# description_sentence_word_dtm_0_1__binary_tf__c...    0.001443
# title_word_2gram_dtm_0_1__tfidf__cosine               0.001440
# title_word_1_2gram_dtm_0__tf__cosine                  0.001431
# title_word_2gram_dtm_0__tf__cosine                    0.001403
# description_sentence_word_dtm_1_1__binary_tf__c...    0.001374
# title_word_1_2gram_dtm_0__binary_tfidf__cosine        0.001343
# title_word_dtm_1_1__tfidf__cosine                     0.001343
# title_word_dtm_1_1__binary_tfidf__cosine              0.001320
# title_word_2gram_dtm_0_1__tf__cosine                  0.001297
# title_word_dtm_1__tf__cosine                          0.001257
# title_word_dtm_0__tf__cosine                          0.001175
# title_word_1_2gram_dtm_0__binary_tf__cosine           0.001109
# title_word_dtm_1__binary_tfidf__cosine                0.001101
# description_word_dtm_1_1__max_disjoint_idf_max        0.001064
# title_word_dtm_0_1__tf__cosine                        0.001058
# title_word_2gram_dtm_0__binary_tfidf__cosine          0.000992
# title_word_dtm_1_1__tf__cosine                        0.000935
# title_word_dtm_0__binary_tf__cosine                   0.000907
# title_word_dtm_1__binary_tf__cosine                   0.000904
# title_word_dtm_0_1__binary_tf__cosine                 0.000741
# title_word_dtm_1_1__binary_tf__cosine                 0.000659
# title_word_2gram_dtm_0_1__binary_tf__cosine           0.000567
# title_word_2gram_dtm_0_1__binary_tfidf__cosine        0.000547
# title_word_2gram_dtm_0__binary_tf__cosine             0.000488
# description_sentence_word_dtm_1__binary_tf__cos...    0.000351
# description_sentence_word_dtm_0__binary_tf__cos...    0.000339
# description_sentence_word_dtm_1_1__binary_tf__c...    0.000308
# description_sentence_word_dtm_0_1__binary_tf__c...    0.000265
#
# [110 rows x 1 columns]

# %%
show(Bar(feature_importance.head(50), label=CatAttr(columns=['feature'], sort=False), values='importance',
        plot_width=1000))
# Out:
#     <div class="plotdiv" id="69a26720-c6aa-4b39-98e1-bf9330f8ec79"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("69a26720-c6aa-4b39-98e1-bf9330f8ec79");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '69a26720-c6aa-4b39-98e1-bf9330f8ec79' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b4c304b8-f737-40cc-9eb0-6a0ded3e1919":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"index":26}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.9513431016002241],"index":[26],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["26"],"y":[0.47567155080011203]}},"id":"fa0a6102-8c2a-49ff-a496-24eef0ebf084","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"index":39}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.9617537725996418],"index":[39],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["39"],"y":[0.4808768862998209]}},"id":"04173b4b-15c0-44a4-a419-f115528bcca6","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1f8dcf4b-9f24-4e3a-b93f-5544b8b6f93c","type":"Rect"},{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"feature":"price_max"}],"color":["#f22c40"],"feature":["price_max"],"fill_alpha":[0.8],"height":[0.010720985941588879],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["price_max"],"y":[0.005360492970794439]}},"id":"a044018b-38ba-46df-94e0-e4ba7810c40e","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"f797c55a-ec3a-44b8-934d-bdc64989fb2c","subtype":"Chart","type":"Plot"}},"id":"80c06002-0881-4621-a451-0e5ab5a73646","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"index":40}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.9604367713742212],"index":[40],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["40"],"y":[0.4802183856871106]}},"id":"6978881b-3f2a-4df2-8a7d-f7a3e35725fe","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e3eccef5-7326-40c5-89f4-d8128e16746b","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"451757ac-0e82-4272-b76c-69c3248cf6da","type":"Rect"},{"attributes":{},"id":"42684e08-607f-4440-a71a-edb0ab774c3a","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"7d6279fb-2af2-4d0c-9c0c-2910d1ddb59a","type":"ColumnDataSource"},"glyph":{"id":"cf55e39f-b82c-4705-aa40-a2cc4a7beeea","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d2276e76-ac2b-4f5d-ab01-4ff631ccfadc","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"55d1e41d-593c-4be0-8b56-d62b223caa32","type":"Rect"},{"attributes":{"callback":null,"column_names":["color","x","line_color","line_alpha","y","height","width","fill_alpha"],"data":{"chart_index":[{"isDuplicate":1}],"color":["#5ab738"],"fill_alpha":[0.6],"height":[126.0],"isDuplicate":[1],"line_alpha":[1.0],"line_color":["black"],"width":[0.03395000000000001],"x":["0.915"],"y":[63.0]}},"id":"789cb0d8-eae2-4e66-82b4-89cfb1e7c19f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"fi ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[62]</strong>&gt;</code></p>

# %%
model_name = 'xgboost.39.weighted'

# %%
# %%time
model.fit(features_train, item_pairs_train.isDuplicate, sample_weight=weight)
prob_test = model.predict_proba(features_test)[:,1]

pickle.dump(model, open(model_name+'.pickle', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)
pd.DataFrame({'id': item_pairs_test['id'], 'probability': prob_test}).to_csv(model_name+'.csv', index=False)
# Out:
# CPU times: user 1d 17h 9min 6s, sys: 2min 1s, total: 1d 17h 11min 8s
# Wall time: 1h 35min 21s

# %%
# %%time
model_name = 'xgboost.39.tuning.1'
model = XGBClassifier(learning_rate=0.05, max_depth=10, subsample=0.8, colsample_bytree=0.8, n_estimators=1000,
                      min_child_weight = 1,
                      nthread=32)
model.fit(features_train, item_pairs_train.isDuplicate, sample_weight=weight)
prob_test = model.predict_proba(features_test)[:,1]

pickle.dump(model, open(model_name+'.pickle', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)
pd.DataFrame({'id': item_pairs_test['id'], 'probability': prob_test}).to_csv(model_name+'.csv', index=False)
# Out:
# CPU times: user 3d 10h 19min 40s, sys: 2min 51s, total: 3d 10h 22min 32s
# Wall time: 3h 4min 33s

# %%
# %%time
model_name = 'xgboost.39.tuning.2'
model = XGBClassifier(learning_rate=0.1, max_depth=10, subsample=0.8, colsample_bytree=0.8, n_estimators=500,
                      min_child_weight = 1,
                      nthread=32)
model.fit(features_train, item_pairs_train.isDuplicate, sample_weight=weight)
prob_test = model.predict_proba(features_test)[:,1]

pickle.dump(model, open(model_name+'.pickle', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)
pd.DataFrame({'id': item_pairs_test['id'], 'probability': prob_test}).to_csv(model_name+'.csv', index=False)
# Out:
# CPU times: user 1d 16h 49min 8s, sys: 1min 41s, total: 1d 16h 50min 49s
# Wall time: 1h 31min 34s
